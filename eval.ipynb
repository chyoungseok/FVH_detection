# %%
import pandas as pd

df = pd.read_csv('/zdisk/users/ext_user_03/01_yschoi/project_01_FVH_detection/runs/resnet_03_whole_p1n2_focal_depth34_batch64.yaml/test_metrics.csv')
df.T
# Out:
#                        0
# auc             0.811944
# precision       0.578125
# acc             0.722222
# f1              0.596774
# recall          0.616667
# f1_best         0.670886
# thr_best        0.191307
# precision_best  0.540816
# recall_best     0.883333
# loss            0.353808
